# %%
#r "nuget: ScottPlot, 5.0.5-beta"
// Setup a custom formatter to display plots as images
using Microsoft.DotNet.Interactive.Formatting;
Formatter.Register(typeof(ScottPlot.Plot), (p, w) => 
    w.Write(((ScottPlot.Plot)p).GetImageHtml(1200,800)), HtmlFormatter.MimeType);
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>ScottPlot, 5.0.5-beta</span></li></ul></div></div>

# %%
ScottPlot.Plot myPlot = new();

double[] dataX = { 1, 2, 3, 4, 5 };
double[] dataY = { 1, 4, 9, 16, 25 };
myPlot.Add.Scatter(dataX, dataY);
myPlot.SavePng("scatter-plot.png",1200,800);
myPlot
# Out:
# <img src="data:image/png;base64,..."></img>

# %%
using System.Drawing;
using ScottPlot;

ScottPlot.Plot myPlot = new();

myPlot.Add.Signal(Generate.Sin(51));
myPlot.Add.Signal(Generate.Cos(51));

myPlot.XAxis.Label.Text = "Horizonal Axis";
myPlot.YAxis.Label.Text = "Vertical Axis";
myPlot.Title.Label.Text = "Plot Title";

myPlot.SavePng("axis-labels.png",1200,800);
myPlot
# Out:
# <img src="data:image/png;base64,..."></img>
