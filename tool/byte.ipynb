# %%
#r "nuget: DotNetty.Buffers, 0.7.5"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>DotNetty.Buffers, 0.7.5</span></li></ul></div></div>

# %%
using System;
using System.IO;
using System.Collections.Generic;
using System.Linq;
using System.Runtime.InteropServices;
using System.Text;
using System.Threading.Tasks;
using DotNetty.Buffers;

# %%
// 方式一
using (System.IO.FileStream fs = new System.IO.FileStream(@"D:\test\dara\JXYH_001_20230326033555_CH3_Cond1.dat", System.IO.FileMode.Open))
{
    // 获取文件大小
    long size = fs.Length;
    byte[] bytes = new byte[size];
    // 将文件读到byte数组中
    fs.Read(bytes, 0, bytes.Length);
    display(bytes.Length);
    IByteBuffer buffer = Unpooled.WrappedBuffer(bytes);
    display(buffer.ReadShortLE());//Header Version
    display(buffer.ReadIntLE());//Data Size
    display(buffer.ReadShortLE());//Data Analysis
    display(buffer.ReadFloatLE());//Scale Coefficient
    display(buffer.ReadFloatLE());//Scale Offset
    buffer.ReadBytes(new byte[48]);//Scale Offset
    display(buffer.ReadShortLE());//Condition Description Size
    buffer.ReadBytes(new byte[14]);//Scale Offset
    display(buffer.ReadBytes(new byte[16]));//Working Condition
    display(buffer.ReadBytes(new byte[16]));//Working Condition
    display(buffer.ReadBytes(new byte[16]));//Working Condition
    display(buffer.ReadBytes(new byte[16]));//Working Condition
    display(buffer.ReadFloatLE());//Working Condition
    display(buffer.ReadFloatLE());//Working Condition
    display(buffer.ReadFloatLE());//Working Condition
    display(buffer.ReadFloatLE());//Working Condition
    display(buffer.ReadFloatLE());//Working Condition
    display(buffer.ReadFloatLE());//Working Condition
    display(buffer.ReadFloatLE());//Working Condition
    display(buffer.ReadFloatLE());//Working Condition
    display(buffer.ReadFloatLE());//Working Condition
    display(buffer.ReadFloatLE());//Working Condition
    display(buffer.ReadFloatLE());//Working Condition
    display(buffer.ReadFloatLE());//Working Condition
    display(buffer.ReadBytes(new byte[16]));//Working Condition
    display(buffer.ReadBytes(new byte[32]));//Working Condition
    display(buffer.ReadIntLE());//Working Condition
    display(buffer.ReadBytes(new byte[28]));//Working Condition
    display(buffer.ReadFloatLE());//Working Condition
}
# Out:
# <div class="dni-plaintext"><pre>524800</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <div class="dni-plaintext"><pre>139</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <div class="dni-plaintext"><pre>64</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <div class="dni-plaintext"><pre>2</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <div class="dni-plaintext"><pre>1</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <div class="dni-plaintext"><pre>0</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <div class="dni-plaintext"><pre>12</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>UnpooledHeapByteBuffer(ridx: 96, widx: 524800, cap: 524800/524800)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Allocator</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>DotNetty.Buffers.UnpooledByteBufferAllocator</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>IsDirectBufferPooled</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>Metric</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>UnpooledByteBufferAllocatorMetric (usedHeapMemory: 0; usedDirectMemory: 0)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>UsedHeapMemory</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>UsedDirectMemory</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td>IsDirect</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>Capacity</td><td><div class="dni-plaintext"><pre>524800</pre></div></td></tr><tr><td>HasArray</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>Array</td><td><div class="dni-plaintext"><pre>[ 139, 0, 64, 0, 0, 0, 2, 0, 0, 0, 128, 63, 0, 0, 0, 0, 0, 0, 0, 0 ... (524780 more) ]</pre></div></td></tr><tr><td>ArrayOffset</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>HasMemoryAddress</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>IoBufferCount</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>ReferenceCount</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>MaxCapacity</td><td><div class="dni-plaintext"><pre>524800</pre></div></td></tr><tr><td>ReaderIndex</td><td><div class="dni-plaintext"><pre>96</pre></div></td></tr><tr><td>WriterIndex</td><td><div class="dni-plaintext"><pre>524800</pre></div></td></tr><tr><td>ReadableBytes</td><td><div class="dni-plaintext"><pre>524704</pre></div></td></tr><tr><td>WritableBytes</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>MaxWritableBytes</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr></tbody></table></div></details><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>UnpooledHeapByteBuffer(ridx: 112, widx: 524800, cap: 524800/524800)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Allocator</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>DotNetty.Buffers.UnpooledByteBufferAllocator</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>IsDirectBufferPooled</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>Metric</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>UnpooledByteBufferAllocatorMetric (usedHeapMemory: 0; usedDirectMemory: 0)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>UsedHeapMemory</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>UsedDirectMemory</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td>IsDirect</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>Capacity</td><td><div class="dni-plaintext"><pre>524800</pre></div></td></tr><tr><td>HasArray</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>Array</td><td><div class="dni-plaintext"><pre>[ 139, 0, 64, 0, 0, 0, 2, 0, 0, 0, 128, 63, 0, 0, 0, 0, 0, 0, 0, 0 ... (524780 more) ]</pre></div></td></tr><tr><td>ArrayOffset</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>HasMemoryAddress</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>IoBufferCount</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>ReferenceCount</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>MaxCapacity</td><td><div class="dni-plaintext"><pre>524800</pre></div></td></tr><tr><td>ReaderIndex</td><td><div class="dni-plaintext"><pre>112</pre></div></td></tr><tr><td>WriterIndex</td><td><div class="dni-plaintext"><pre>524800</pre></div></td></tr><tr><td>ReadableBytes</td><td><div class="dni-plaintext"><pre>524688</pre></div></td></tr><tr><td>WritableBytes</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>MaxWritableBytes</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr></tbody></table></div></details><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>UnpooledHeapByteBuffer(ridx: 128, widx: 524800, cap: 524800/524800)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Allocator</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>DotNetty.Buffers.UnpooledByteBufferAllocator</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>IsDirectBufferPooled</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>Metric</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>UnpooledByteBufferAllocatorMetric (usedHeapMemory: 0; usedDirectMemory: 0)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>UsedHeapMemory</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>UsedDirectMemory</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td>IsDirect</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>Capacity</td><td><div class="dni-plaintext"><pre>524800</pre></div></td></tr><tr><td>HasArray</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>Array</td><td><div class="dni-plaintext"><pre>[ 139, 0, 64, 0, 0, 0, 2, 0, 0, 0, 128, 63, 0, 0, 0, 0, 0, 0, 0, 0 ... (524780 more) ]</pre></div></td></tr><tr><td>ArrayOffset</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>HasMemoryAddress</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>IoBufferCount</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>ReferenceCount</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>MaxCapacity</td><td><div class="dni-plaintext"><pre>524800</pre></div></td></tr><tr><td>ReaderIndex</td><td><div class="dni-plaintext"><pre>128</pre></div></td></tr><tr><td>WriterIndex</td><td><div class="dni-plaintext"><pre>524800</pre></div></td></tr><tr><td>ReadableBytes</td><td><div class="dni-plaintext"><pre>524672</pre></div></td></tr><tr><td>WritableBytes</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>MaxWritableBytes</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr></tbody></table></div></details><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>UnpooledHeapByteBuffer(ridx: 144, widx: 524800, cap: 524800/524800)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Allocator</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>DotNetty.Buffers.UnpooledByteBufferAllocator</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>IsDirectBufferPooled</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>Metric</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>UnpooledByteBufferAllocatorMetric (usedHeapMemory: 0; usedDirectMemory: 0)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>UsedHeapMemory</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>UsedDirectMemory</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td>IsDirect</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>Capacity</td><td><div class="dni-plaintext"><pre>524800</pre></div></td></tr><tr><td>HasArray</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>Array</td><td><div class="dni-plaintext"><pre>[ 139, 0, 64, 0, 0, 0, 2, 0, 0, 0, 128, 63, 0, 0, 0, 0, 0, 0, 0, 0 ... (524780 more) ]</pre></div></td></tr><tr><td>ArrayOffset</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>HasMemoryAddress</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>IoBufferCount</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>ReferenceCount</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>MaxCapacity</td><td><div class="dni-plaintext"><pre>524800</pre></div></td></tr><tr><td>ReaderIndex</td><td><div class="dni-plaintext"><pre>144</pre></div></td></tr><tr><td>WriterIndex</td><td><div class="dni-plaintext"><pre>524800</pre></div></td></tr><tr><td>ReadableBytes</td><td><div class="dni-plaintext"><pre>524656</pre></div></td></tr><tr><td>WritableBytes</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>MaxWritableBytes</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr></tbody></table></div></details><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <div class="dni-plaintext"><pre>0</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <div class="dni-plaintext"><pre>0</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <div class="dni-plaintext"><pre>0</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <div class="dni-plaintext"><pre>1777.8864</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <div class="dni-plaintext"><pre>1777.8864</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <div class="dni-plaintext"><pre>1777.8864</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <div class="dni-plaintext"><pre>0</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <div class="dni-plaintext"><pre>0</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <div class="dni-plaintext"><pre>0</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <div class="dni-plaintext"><pre>0</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <div class="dni-plaintext"><pre>0</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <div class="dni-plaintext"><pre>0</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>UnpooledHeapByteBuffer(ridx: 208, widx: 524800, cap: 524800/524800)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Allocator</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>DotNetty.Buffers.UnpooledByteBufferAllocator</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>IsDirectBufferPooled</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>Metric</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>UnpooledByteBufferAllocatorMetric (usedHeapMemory: 0; usedDirectMemory: 0)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>UsedHeapMemory</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>UsedDirectMemory</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td>IsDirect</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>Capacity</td><td><div class="dni-plaintext"><pre>524800</pre></div></td></tr><tr><td>HasArray</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>Array</td><td><div class="dni-plaintext"><pre>[ 139, 0, 64, 0, 0, 0, 2, 0, 0, 0, 128, 63, 0, 0, 0, 0, 0, 0, 0, 0 ... (524780 more) ]</pre></div></td></tr><tr><td>ArrayOffset</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>HasMemoryAddress</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>IoBufferCount</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>ReferenceCount</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>MaxCapacity</td><td><div class="dni-plaintext"><pre>524800</pre></div></td></tr><tr><td>ReaderIndex</td><td><div class="dni-plaintext"><pre>208</pre></div></td></tr><tr><td>WriterIndex</td><td><div class="dni-plaintext"><pre>524800</pre></div></td></tr><tr><td>ReadableBytes</td><td><div class="dni-plaintext"><pre>524592</pre></div></td></tr><tr><td>WritableBytes</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>MaxWritableBytes</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr></tbody></table></div></details><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>UnpooledHeapByteBuffer(ridx: 240, widx: 524800, cap: 524800/524800)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Allocator</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>DotNetty.Buffers.UnpooledByteBufferAllocator</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>IsDirectBufferPooled</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>Metric</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>UnpooledByteBufferAllocatorMetric (usedHeapMemory: 0; usedDirectMemory: 0)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>UsedHeapMemory</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>UsedDirectMemory</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td>IsDirect</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>Capacity</td><td><div class="dni-plaintext"><pre>524800</pre></div></td></tr><tr><td>HasArray</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>Array</td><td><div class="dni-plaintext"><pre>[ 139, 0, 64, 0, 0, 0, 2, 0, 0, 0, 128, 63, 0, 0, 0, 0, 0, 0, 0, 0 ... (524780 more) ]</pre></div></td></tr><tr><td>ArrayOffset</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>HasMemoryAddress</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>IoBufferCount</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>ReferenceCount</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>MaxCapacity</td><td><div class="dni-plaintext"><pre>524800</pre></div></td></tr><tr><td>ReaderIndex</td><td><div class="dni-plaintext"><pre>240</pre></div></td></tr><tr><td>WriterIndex</td><td><div class="dni-plaintext"><pre>524800</pre></div></td></tr><tr><td>ReadableBytes</td><td><div class="dni-plaintext"><pre>524560</pre></div></td></tr><tr><td>WritableBytes</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>MaxWritableBytes</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr></tbody></table></div></details><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <div class="dni-plaintext"><pre>131072</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>UnpooledHeapByteBuffer(ridx: 272, widx: 524800, cap: 524800/524800)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Allocator</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>DotNetty.Buffers.UnpooledByteBufferAllocator</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>IsDirectBufferPooled</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>Metric</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>UnpooledByteBufferAllocatorMetric (usedHeapMemory: 0; usedDirectMemory: 0)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>UsedHeapMemory</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>UsedDirectMemory</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td>IsDirect</td><td><div class="dni-plaintext"><pre>False</pre></div></td></tr><tr><td>Capacity</td><td><div class="dni-plaintext"><pre>524800</pre></div></td></tr><tr><td>HasArray</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>Array</td><td><div class="dni-plaintext"><pre>[ 139, 0, 64, 0, 0, 0, 2, 0, 0, 0, 128, 63, 0, 0, 0, 0, 0, 0, 0, 0 ... (524780 more) ]</pre></div></td></tr><tr><td>ArrayOffset</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>HasMemoryAddress</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>IoBufferCount</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>ReferenceCount</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>MaxCapacity</td><td><div class="dni-plaintext"><pre>524800</pre></div></td></tr><tr><td>ReaderIndex</td><td><div class="dni-plaintext"><pre>272</pre></div></td></tr><tr><td>WriterIndex</td><td><div class="dni-plaintext"><pre>524800</pre></div></td></tr><tr><td>ReadableBytes</td><td><div class="dni-plaintext"><pre>524528</pre></div></td></tr><tr><td>WritableBytes</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>MaxWritableBytes</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr></tbody></table></div></details><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <div class="dni-plaintext"><pre>5120</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
